# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Laptop_Information.csv', index_col=0)

# %%
df.head()
# Out:
#   Company  Rating  No_of_ratings  Review  Size  \
# 0      HP     4.2            253      20  36.0
# 1  Lenovo     4.2            974      75  36.0
# 2    ASUS     4.4           5389     535  40.0
# 3    DELL     4.1            332      26  40.0
# 4    ASUS     4.2            487      53  40.0
#
#                                            Processor  RAM  \
# 0                    AMD Ryzen 5 Hexa Core Processor   16
# 1                 Intel Core i3 Processor (11th Gen)    8
# 2                 Intel Core i5 Processor (10th Gen)    8
# 3  Processor: Intel i3-1115G4 (Base- 1.7 GHz & Tu...    8
# 4                 Intel Core i3 Processor (11th Gen)    8
#
#                                     Memory  \
# 0                               512 GB SSD
# 1                               256 GB SSD
# 2                               512 GB SSD
# 3  Display: 15.6" FHD WVA AG Narrow Border
# 4                               512 GB SSD
#
# ...

# %% [markdown]
# Current conversion rate from Indian Rupee to USD is 1.00000 INR = 0.01220

# %%
df.dtypes
# Out:
# Company           object
# Rating           float64
# No_of_ratings      int64
# Review             int64
# Size             float64
# Processor         object
# RAM                int64
# Memory            object
# OpSys             object
# Price              int64
# MRP                int64
# ImgURL            object
# dtype: object

# %%
df['Price'] = df['Price'] * 0.01220

# %%
df['MRP'] = df['MRP'] * 0.01220

# %%
df.head()
# Out:
#   company  rating  no_of_ratings  review  size  \
# 0      HP     4.2            253      20  36.0
# 1  Lenovo     4.2            974      75  36.0
# 2    ASUS     4.4           5389     535  40.0
# 3    DELL     4.1            332      26  40.0
# 4    ASUS     4.2            487      53  40.0
#
#                                            processor  ram  \
# 0                    AMD Ryzen 5 Hexa Core Processor   16
# 1                 Intel Core i3 Processor (11th Gen)    8
# 2                 Intel Core i5 Processor (10th Gen)    8
# 3  Processor: Intel i3-1115G4 (Base- 1.7 GHz & Tu...    8
# 4                 Intel Core i3 Processor (11th Gen)    8
#
#                                     memory  \
# 0                               512 GB SSD
# 1                               256 GB SSD
# 2                               512 GB SSD
# 3  Display: 15.6" FHD WVA AG Narrow Border
# 4                               512 GB SSD
#
# ...

# %%
df.columns = df.columns.str.lower()

# %%
df.head()
# Out:
#   company  rating  no_of_ratings  review  size  \
# 0      HP     4.2            253      20  36.0
# 1  Lenovo     4.2            974      75  36.0
# 2    ASUS     4.4           5389     535  40.0
# 3    DELL     4.1            332      26  40.0
# 4    ASUS     4.2            487      53  40.0
#
#                                            processor  ram  \
# 0                    AMD Ryzen 5 Hexa Core Processor   16
# 1                 Intel Core i3 Processor (11th Gen)    8
# 2                 Intel Core i5 Processor (10th Gen)    8
# 3  Processor: Intel i3-1115G4 (Base- 1.7 GHz & Tu...    8
# 4                 Intel Core i3 Processor (11th Gen)    8
#
#                                     memory  \
# 0                               512 GB SSD
# 1                               256 GB SSD
# 2                               512 GB SSD
# 3  Display: 15.6" FHD WVA AG Narrow Border
# 4                               512 GB SSD
#
# ...

# %%
col_to_lower = ['memory', 'opsys', 'company', 'processor']

for col in col_to_lower:
    
    df[col] = df[col].str.lower()

# %%
df.head()
# Out:
#   company  rating  no_of_ratings  review  size  \
# 0      hp     4.2            253      20  36.0
# 1  lenovo     4.2            974      75  36.0
# 2    asus     4.4           5389     535  40.0
# 3    dell     4.1            332      26  40.0
# 4    asus     4.2            487      53  40.0
#
#                                            processor  ram  \
# 0                    amd ryzen 5 hexa core processor   16
# 1                 intel core i3 processor (11th gen)    8
# 2                 intel core i5 processor (10th gen)    8
# 3  processor: intel i3-1115g4 (base- 1.7 ghz & tu...    8
# 4                 intel core i3 processor (11th gen)    8
#
#                                     memory  \
# 0                               512 gb ssd
# 1                               256 gb ssd
# 2                               512 gb ssd
# 3  display: 15.6" fhd wva ag narrow border
# 4                               512 gb ssd
#
# ...

# %%
df['imgurl'][0]
# Out:
# 'https://rukminim1.flixcart.com/image/312/312/l5fnhjk0/computer/c/p/c/14s-fy1005au-thin-and-light-laptop-hp-original-imagg4dgtu77mzye.jpeg?q=70'

# %% [markdown]
# **Goals**:
#
# - ML Model that will cluster the laptops based off of:
#
#     - price
#     - mrp
#     - processing power
#     - screen size
#     - rating / num ratings
#
# - Clusters valuable enough to use in a classification model
#
# **Questions to ask**:
#
# - Is price related to ratings? Number of ratings?
# - How are price and screen size related?
# - Is price related to processor?
#
# **Measures of Success**:
#
# - Finding top features
# - A viable model that achieves our goals
# - How will we use this?
#
# **How to Achieve**:
#
# - Clean data
# - Explore data:
#     - find anomalies
#     - statistical tests
#     - visualizations
# - Determine most important features
#
# **Deliverable**:
#
# - Reproducable githut repository for other users to rank laptops based upon various features.

# %%
df['ram'].unique()
# Out:
# array([16,  8,  4, 32])

# %%
df['processor'].unique()
# Out:
# array(['amd ryzen 5 hexa core processor',
#        'intel core i3 processor (11th gen)',
#        'intel core i5 processor (10th gen)',
#        'processor: intel i3-1115g4 (base- 1.7 ghz & turbo up to 4.10 ghz) 2 cores',
#        'intel core i5 processor (11th gen)',
#        'intel celeron dual core processor',
#        'amd ryzen 7 octa core processor',
#        'processor: intel i5-1235u (base- 3.30 ghz & turbo up to 4.40 ghz) 10 cores',
#        'intel core i5 processor (12th gen)',
#        'amd athlon dual core processor',
#        'intel core i3 processor (10th gen)',
#        'intel core i7 processor (11th gen)', 'apple m2 processor',
#        'apple m2 max processor', 'amd ryzen 3 quad core processor',
#        'apple m1 processor', 'intel core i7 processor (12th gen)',
#        'processor: amdr5-6600h (3.30 ghz up to 4.50 ghz 6 cores 16mb l3 cache)',
#        'intel core i9 processor (13th gen)',
#        'intel core i7 processor (10th gen)',
# ...
